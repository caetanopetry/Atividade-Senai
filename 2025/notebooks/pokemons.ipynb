# %% [markdown]
# <a href="https://colab.research.google.com/github/caetanopetry/Atividade-Senai/blob/main/notebooks/pokemons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Pokémon
#
# Neste notebook você vai praticar Pandas usando dados de Pokémon.
# Use o exemplo do tutorial anterior para ajudá-lo a preencher os códigos.

# %% [markdown]
# ## Arquivo base
# O CSV `pokemon.csv` contém colunas como `Name`, `Type 1`, `Type 2`, `Total`, `HP`, `Attack`, `Defense`, `Sp. Atk`, `Sp. Def`, `Speed`, `Generation`, `Legendary`.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/lukas-senai/pandas-tutorial/main/assets/pokemons.csv"
df = pd.read_csv(url)

df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ## 2️⃣ Seleção de colunas
# - Mostrar apenas a coluna `Name`
# - Mostrar as colunas `Name` e `Type 1`

# %%
df[["Name"]]
df[["Name", "Type 1"]]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %% [markdown]
# ## 3️⃣ Filtrando dados
# - Mostrar todos os Pokémon do tipo "Water"
# - Mostrar todos os Pokémon da Geração 1
# - Mostrar todos os Pokémon com HP maior que 70
# - Mostrar Pokémon com Attack >= 100
# - Filtrar apenas Pokémon Legendary (Legendary == True)

# %%
# pokemonagua = df[df["Type 2"] == "Water"]
# pokemonagua

# geracao1 = df[df["Generation"] == 1]
# geracao1

# hpmaiorq70 = df[df["HP"] > 70]
# hpmaiorq70

# atkmaior_ig_100 = df[df["Attack"] >= 100]
# atkmaior_ig_100


legendarios = df[df["Legendary"] == True]
legendarios
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# ...

# %% [markdown]
# ## 4️⃣ Estatísticas simples
# - Calcular a média da coluna Total
# - Descobrir o maior Total
# - Descobrir o menor Total
# - Calcular a média de Attack dos Pokémons da Geração 1
# - Calcular a média de Attack dos Pokémons da Geração 6
# - Calcular a médie de HP dos Pokémons do tipo Fire
# - Calcular a médie de HP dos Pokémons do tipo Water

# %%
media_colum_total = df["Total"].mean()
print(f"Média da coluna total: {media_colum_total}")

maior_total = df["Total"].max()
print(f"Maior Total: {maior_total}")

menor_total = df["Total"].min()
print(f"Maior Total: {menor_total}")

media_attack_gen_1= df[df["Generation"]==1]["Attack"].mean()
print(f"Media de Attack dos Pokemóns da geração 1: {media_attack_gen_1:.2f} ")

media_attack_gen_6= df[df["Generation"]==6]["Attack"].mean()
print(f"Media de Attack dos Pokemóns da geração 6: {media_attack_gen_6:.2f} ")

media_hp_fire = df[df["Type 1"]== "Fire"]["HP"].mean()
print(f"Média de HP dos Pokémons do tipo Fire: {media_hp_fire:.2f}")

media_hp_water= df[df["Type 1"]== "Water"]["HP"].mean()
print(f"Média de HP dos Pokémons do tipo Water: {media_hp_water:.2f}")
# Out:
# Média da coluna total: 435.1025
# Maior Total: 780
# Maior Total: 180
# Media de Attack dos Pokemóns da geração 1: 76.64
# Media de Attack dos Pokemóns da geração 6: 75.80
# Média de HP dos Pokémons do tipo Fire: 69.90
# Média de HP dos Pokémons do tipo Water: 72.06

# %% [markdown]
# ## 5️⃣ Ordenação
# - Ordenar os Pokémon por Total do maior para o menor.
# - Ordenar os Pokémon por Speed do menor para o maior.

# %%
ordernartotal = df.sort_values(by="Total", ascending=True)
ordernartotal

ordernarspeed = df.sort_values(by="Speed", ascending=True)
ordernarspeed
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 495  446                   Munchlax   Normal     NaN    390  135      85
# 230  213                    Shuckle      Bug    Rock    505   20      10
# 359  328                   Trapinch   Ground     NaN    290   45     100
# 486  438                     Bonsly     Rock     NaN    290   50      80
# 658  597                  Ferroseed    Grass   Steel    305   44      50
# ..   ...                        ...      ...     ...    ...  ...     ...
# 428  386         DeoxysNormal Forme  Psychic     NaN    600   50     150
# 154  142  AerodactylMega Aerodactyl     Rock  Flying    615   80     135
# 429  386         DeoxysAttack Forme  Psychic     NaN    600   50     180
# 315  291                    Ninjask      Bug  Flying    456   61      90
# 431  386          DeoxysSpeed Forme  Psychic     NaN    600   50      95
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## 5️⃣ Exploração rápida
# - Contar quantos Pokémon são Legendary
# - Mostrar os 5 primeiros Pokémon do CSV

# %%
print("Pokemóns que são legendary:", df[df["Legendary"] >= True].shape[0])
print(f"Os 5 primeiros pokemóns da tabela são: ", df['Name'].head(5).to_string(index=False))
# Out:
# Pokemóns que são legendary: 65
# Os 5 primeiros pokemóns da tabela são:              Bulbasaur
#               Ivysaur
#              Venusaur
# VenusaurMega Venusaur
#            Charmander

# %% [markdown]
# ## 🔹 Desafios (opcional)
# 1. Mostrar o Pokémon mais rápido (`Speed`)
# 2. Mostrar o Pokémon do tipo Fire com maior `Attack`
# 3. Mostrar o Pokémon do tipo Rock com maior `HP`
# 4. Listar os Pokémon Legendary da primeira geração
# 5. Escreva qual é o seu Pokémon favorito

# %%
ordernarfire = df[df['Type 1'] == 'Fire'].sort_values("Attack", ascending=True)
ordernarrockhp = df[df['Type 1'] == 'Rock'].sort_values("HP", ascending=True)





maisrapido = ordernarspeed["Name"].iloc[0]
print(f"O pokemon mais rápido é o {maisrapido}")



firemaioratk = ordernarfire["Name"].iloc[0]
print(f"O pokemon do tipo Fire com maior Attack é o {firemaioratk}")

maiorhprock = ordernarrockhp["Name"].iloc[0]

print(f"O pokemon do Rock com maior HP é o {maiorhprock}")


ordernarlegendary = df[(df['Legendary'] == True) & (df["Generation"] == 1)]
print(ordernarlegendary)

print("Charizard")
# Out:
# O pokemon mais rápido é o DeoxysSpeed Forme
# O pokemon do tipo Fire com maior Attack é o DarmanitanZen Mode
# O pokemon do Rock com maior HP é o Kabuto
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150  MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# ...
